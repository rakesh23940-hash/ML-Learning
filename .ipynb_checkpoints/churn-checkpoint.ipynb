# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("patient_churn_dataset.csv")

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender  Tenure_Months  Visits_Last_Year Chronic_Disease  \
# 0           1   56  Female              2                 3              No
# 1           2   69    Male             10                 3             Yes
# 2           3   46  Female             56                10              No
# 3           4   32    Male             30                 4             Yes
# 4           5   60    Male             50                19              No
#
#   Insurance_Type  Satisfaction_Score  Total_Bill_Amount  Missed_Appointments  \
# 0     Government                 2.5           12252.96                    9
# 1     Government                 2.6           25862.01                    4
# 2            NaN                 2.8            5659.13                    4
# 3     Government                 4.1           19533.31                    5
# 4        Private                 4.6           24639.52                    5
#
#    Churn
# 0      1
# 1      0
# 2      0
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Tenure_Months', 'Visits_Last_Year',
#        'Chronic_Disease', 'Insurance_Type', 'Satisfaction_Score',
#        'Total_Bill_Amount', 'Missed_Appointments', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (500, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           500 non-null    int64
#  1   Age                  500 non-null    int64
#  2   Gender               500 non-null    object
#  3   Tenure_Months        500 non-null    int64
#  4   Visits_Last_Year     500 non-null    int64
#  5   Chronic_Disease      500 non-null    object
#  6   Insurance_Type       350 non-null    object
#  7   Satisfaction_Score   500 non-null    float64
#  8   Total_Bill_Amount    500 non-null    float64
#  9   Missed_Appointments  500 non-null    int64
#  10  Churn                500 non-null    int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 43.1+ KB

# %%
df.describe()
# Out:
#        Patient_ID         Age  Tenure_Months  Visits_Last_Year  \
# count  500.000000  500.000000     500.000000        500.000000
# mean   250.500000   49.910000      29.498000          9.412000
# std    144.481833   18.221909      17.402865          5.687086
# min      1.000000   18.000000       1.000000          0.000000
# 25%    125.750000   35.000000      14.000000          4.000000
# 50%    250.500000   50.000000      30.000000          9.000000
# 75%    375.250000   66.000000      45.000000         14.000000
# max    500.000000   79.000000      59.000000         19.000000
#
#        Satisfaction_Score  Total_Bill_Amount  Missed_Appointments       Churn
# count          500.000000          500.00000           500.000000  500.000000
# mean             3.049000        24440.01518             4.422000    0.248000
# std              1.148136        14264.55432             2.908752    0.432284
# min              1.000000          506.67000             0.000000    0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Patient_ID               0
# Age                      0
# Gender                   0
# Tenure_Months            0
# Visits_Last_Year         0
# Chronic_Disease          0
# Insurance_Type         150
# Satisfaction_Score       0
# Total_Bill_Amount        0
# Missed_Appointments      0
# Churn                    0
# dtype: int64

# %%
df['Insurance_Type'] = df.groupby('Age')['Insurance_Type']\
    .transform(lambda x: x.fillna(x.mode()[0]))

# %%
pd.get_dummies(df, columns=['Insurance_Type'], drop_first=True)
# Out:
#      Patient_ID  Age  Gender  Tenure_Months  Visits_Last_Year Chronic_Disease  \
# 0             1   56  Female              2                 3              No
# 1             2   69    Male             10                 3             Yes
# 2             3   46  Female             56                10              No
# 3             4   32    Male             30                 4             Yes
# 4             5   60    Male             50                19              No
# ..          ...  ...     ...            ...               ...             ...
# 495         496   63    Male              2                 4              No
# 496         497   41  Female             27                 3              No
# 497         498   67    Male             31                19             Yes
# 498         499   49    Male             51                 3              No
# 499         500   64    Male             51                17              No
#
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID             0
# Age                    0
# Gender                 0
# Tenure_Months          0
# Visits_Last_Year       0
# Chronic_Disease        0
# Insurance_Type         0
# Satisfaction_Score     0
# Total_Bill_Amount      0
# Missed_Appointments    0
# Churn                  0
# dtype: int64

# %%
df['Churn'].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Churn'>

# %%
import sheryanalysis as sh  
sh.analyze(df)
# Out:
# 🔍 Basic Analysis Report
# ------------------------------------------------------------
# 📏 Shape: (500, 11)
# 🧱 Columns: ['Patient_ID', 'Age', 'Gender', 'Tenure_Months', 'Visits_Last_Year', 'Chronic_Disease', 'Insurance_Type', 'Satisfaction_Score', 'Total_Bill_Amount', 'Missed_Appointments', 'Churn']
#
# ✅ No null values found
#
# 🔠 Categorical Columns: ['Gender', 'Visits_Last_Year', 'Chronic_Disease', 'Insurance_Type', 'Missed_Appointments', 'Churn']
#
# 🔢 Numerical Columns: ['Patient_ID', 'Age', 'Tenure_Months', 'Satisfaction_Score', 'Total_Bill_Amount']
# {'shape': (500, 11),
#  'columns': ['Patient_ID',
#   'Age',
#   'Gender',
#   'Tenure_Months',
#   'Visits_Last_Year',
#   'Chronic_Disease',
#   'Insurance_Type',
#   'Satisfaction_Score',
#   'Total_Bill_Amount',
#   'Missed_Appointments',
#   'Churn'],
#  'dtypes': {'Patient_ID': dtype('int64'),
#   'Age': dtype('int64'),
#   'Gender': dtype('O'),
#   'Tenure_Months': dtype('int64'),
#   'Visits_Last_Year': dtype('int64'),
# ...

# %%
sns.countplot(x = df['Gender'],hue = df['Churn'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df['Chronic_Disease'],hue = df['Churn'])
# Out:
# <Axes: xlabel='Chronic_Disease', ylabel='count'>

# %%
sns.countplot(x = df['Insurance_Type'],hue = df['Churn'])
# Out:
# <Axes: xlabel='Insurance_Type', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plotting(var, num):
    plt.subplot(2, 3, num)   # 2 rows, 3 columns
    sns.histplot(df[var], bins=20, kde=True)
    plt.title(f"{var} Distribution")
    plt.xlabel(var)
    plt.ylabel("Frequency")

# %%
plt.figure(figsize=(15, 8))

plotting('Age', 1)
plotting('Tenure_Months', 2)
plotting('Total_Bill_Amount', 3)


plt.tight_layout()
plt.show()

# %%
sns.boxplot(x = 'Churn',y = 'Total_Bill_Amount',data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='Total_Bill_Amount'>

# %%
sns.boxplot(x = 'Churn',y = 'Visits_Last_Year',data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='Visits_Last_Year'>

# %%
sns.boxplot(x = 'Churn',y = 'Missed_Appointments',data = df)
# Out:
# <Axes: xlabel='Churn', ylabel='Missed_Appointments'>

# %%
sns.violinplot(x='Churn', y='Age', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Age'>

# %%
sns.violinplot(x='Churn', y='Tenure_Months', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Tenure_Months'>

# %%
sns.violinplot(x='Churn', y='Satisfaction_Score', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Satisfaction_Score'>

# %%
sns.violinplot(x='Churn', y='Missed_Appointments', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='Missed_Appointments'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df_encode = pd.get_dummies(df,drop_first=True)

# %%
df_encode
# Out:
#      Patient_ID  Age  Tenure_Months  Visits_Last_Year  Satisfaction_Score  \
# 0             1   56              2                 3                 2.5
# 1             2   69             10                 3                 2.6
# 2             3   46             56                10                 2.8
# 3             4   32             30                 4                 4.1
# 4             5   60             50                19                 4.6
# ..          ...  ...            ...               ...                 ...
# 495         496   63              2                 4                 2.8
# 496         497   41             27                 3                 3.4
# 497         498   67             31                19                 3.5
# 498         499   49             51                 3                 3.4
# 499         500   64             51                17                 3.8
#
#      Total_Bill_Amount  Missed_Appointments  Churn  Gender_Male  \
# ...

# %%
df.drop(["Patient_ID"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Tenure_Months  Visits_Last_Year Chronic_Disease  \
# 0   56  Female              2                 3              No
# 1   69    Male             10                 3             Yes
# 2   46  Female             56                10              No
# 3   32    Male             30                 4             Yes
# 4   60    Male             50                19              No
#
#   Insurance_Type  Satisfaction_Score  Total_Bill_Amount  Missed_Appointments  \
# 0     Government                 2.5           12252.96                    9
# 1     Government                 2.6           25862.01                    4
# 2        Private                 2.8            5659.13                    4
# 3     Government                 4.1           19533.31                    5
# 4        Private                 4.6           24639.52                    5
#
#    Churn
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    250
# Male      250
# Name: count, dtype: int64

# %%
df['Gender'] = df['Gender'].map({"Male" : 0, "Female" : 1})

# %%
df.head()
# Out:
#    Age  Gender  Tenure_Months  Visits_Last_Year Chronic_Disease  \
# 0   56       1              2                 3              No
# 1   69       0             10                 3             Yes
# 2   46       1             56                10              No
# 3   32       0             30                 4             Yes
# 4   60       0             50                19              No
#
#   Insurance_Type  Satisfaction_Score  Total_Bill_Amount  Missed_Appointments  \
# 0     Government                 2.5           12252.96                    9
# 1     Government                 2.6           25862.01                    4
# 2        Private                 2.8            5659.13                    4
# 3     Government                 4.1           19533.31                    5
# 4        Private                 4.6           24639.52                    5
#
#    Churn
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = df_encode.drop('Churn', axis=1)
y = df_encode['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "SVM (RBF Kernel)": SVC(probability=True)
}

# %%
results = []

# %%
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    results.append({
        'Model': name,
        'Accuracy': round(acc, 4),
        'F1 Score': round(f1, 4),
      
    })

# %%
results
# Out:
# [{'Model': 'Logistic Regression', 'Accuracy': 0.75, 'F1 Score': 0.0},
#  {'Model': 'KNN', 'Accuracy': 0.69, 'F1 Score': 0.1622},
#  {'Model': 'Naive Bayes', 'Accuracy': 0.74, 'F1 Score': 0.0},
#  {'Model': 'Decision Tree', 'Accuracy': 0.64, 'F1 Score': 0.28},
#  {'Model': 'SVM (RBF Kernel)', 'Accuracy': 0.75, 'F1 Score': 0.0}]

# %%
# isme ye use nhi krna hai kyuki ye classification data hai  
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.23298613, 0.22844051, 0.26484759, 0.17671521, 0.246694  ,
#        0.2761504 , 0.20673283, 0.2674341 , 0.19336428, 0.2246907 ,
#        0.29255181, 0.31369245, 0.2836928 , 0.20297341, 0.23158059,
#        0.24164544, 0.24464355, 0.17875619, 0.32536538, 0.26261571,
#        0.19749697, 0.25234549, 0.22211062, 0.23109098, 0.19176802,
#        0.22917677, 0.20398812, 0.21463127, 0.26527808, 0.18305314,
#        0.19248056, 0.19723263, 0.30345413, 0.26093546, 0.24340579,
#        0.21420429, 0.22467221, 0.26153158, 0.23364699, 0.28231409,
#        0.20941192, 0.20689772, 0.27894347, 0.20828831, 0.26929459,
#        0.20852276, 0.28623424, 0.28309415, 0.29567755, 0.31387768,
#        0.19497127, 0.32851894, 0.16379735, 0.37945599, 0.25092552,
#        0.20251911, 0.23658993, 0.17828364, 0.16696751, 0.23873769,
#        0.27886841, 0.22095966, 0.2348225 , 0.20660422, 0.32241335,
#        0.27764463, 0.27725712, 0.28370919, 0.2005698 , 0.21364746,
# ...

# %%
y_test
# Out:
# 163    0
# 361    0
# 26     0
# 261    0
# 2      0
#       ..
# 367    0
# 171    0
# 243    0
# 190    0
# 454    0
# Name: Churn, Length: 100, dtype: int64

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_pred)
r2
# Out:
# -0.015544902999168997

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test,y_pred)
r2
n = X_test.shape[0]
p = X_test.shape[1]
adjusted_r2 = 1 - ((1- r2) * (n-1) / (n - p - 1))
adjusted_r2
# Out:
# -0.12965107187547997
