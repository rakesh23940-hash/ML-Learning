# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('modified_placement_data.csv')

# %%
df.head()
# Out:
#   cgpa     iq placement
# 0  6,8  123.0       Yes
# 1  5,9  106.0        No
# 2  5,3  121.0        No
# 3  7,4  132.0       Yes
# 4  5,8  142.0        No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       95 non-null     object
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (100, 3)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of    cgpa     iq placement
# 0   6,8  123.0       Yes
# 1   5,9  106.0        No
# 2   5,3  121.0        No
# 3   7,4  132.0       Yes
# 4   5,8  142.0        No
# ..  ...    ...       ...
# 95  4,3  200.0        No
# 96  4,4   42.0        No
# 97  6,7  182.0       Yes
# 98  6,3  103.0       Yes
# 99  6,2  113.0       Yes
#
# [100 rows x 3 columns]>

# %%
df['cgpa'] = df['cgpa'].str.replace(',', '.', regex=False)

# %%
df['cgpa'] = df['cgpa'].astype(float)

# %%
df['cgpa'] = df['cgpa'].fillna(df['cgpa'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
df['placement'] = df['placement'].map({'Yes': 1, 'No': 0})

# %%
df.head
# Out:
# <bound method NDFrame.head of     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]>

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df[['cgpa', 'iq']]
y = df['placement']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 82   6.5   37.0
# 13   6.4  116.0
# 74   6.7  154.0
# 31   3.9  109.0
# 72   7.3  116.0
# ..   ...    ...
# 26   7.0  199.0
# 73   4.9   61.0
# 57   6.5  130.0
# 61   7.3  137.0
# 87   5.7  132.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 82    1
# 13    1
# 74    1
# 31    0
# 72    1
#      ..
# 26    1
# 73    0
# 57    1
# 61    1
# 87    1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#         cgpa     iq
# 88  4.400000  149.0
# 46  5.300000  114.0
# 66  6.900000   96.0
# 9   5.988421   66.0
# 22  4.900000  120.0
# 91  5.988421  158.0
# 47  5.200000  161.0
# 99  6.200000  113.0
# 11  6.900000  138.0
# 25  5.000000   91.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 4.16162637e-01, -2.13489848e+00],
#        [ 3.28926427e-01, -1.94329803e-01],
#        [ 5.90635058e-01,  7.39108295e-01],
#        [-1.85197883e+00, -3.66278926e-01],
#        [ 1.11405232e+00, -1.94329803e-01],
#        [ 2.41690216e-01,  1.00440123e-01],
#        [-1.15408915e+00, -9.06690457e-01],
#        [-8.92380518e-01, -1.49623031e+00],
#        [-3.01194495e-02,  1.03387822e+00],
#        [-1.06685294e+00,  9.60185739e-01],
#        [-2.81727045e-01,  4.68902530e-01],
#        [-1.94490835e-01,  4.44338369e-01],
#        [-9.79616728e-01,  2.47825086e-01],
#        [ 1.11405232e+00, -1.81556439e+00],
#        [ 8.52343688e-01, -2.92586445e-01],
#        [ 6.77871268e-01, -8.32997975e-01],
#        [ 2.41690216e-01,  7.58759624e-02],
#        [ 5.03398847e-01, -9.60731610e-02],
#        [ 1.37576095e+00,  1.00440123e-01],
#        [ 6.72177957e-02, -5.13663889e-01],
#        [-1.76474262e+00, -5.87356370e-01],
#        [ 2.41690216e-01, -5.13663889e-01],
#        [-7.17908097e-01,  1.98696765e-01],
#        [-1.76474262e+00, -1.20146038e+00],
#        [ 6.72177957e-02,  7.88236616e-01],
#        [ 1.37576095e+00, -8.57562136e-01],
#        [-7.17908097e-01, -8.32997975e-01],
#        [ 8.52343688e-01, -1.47166615e+00],
#        [ 9.39579899e-01,  6.65415814e-01],
#        [-8.05144307e-01,  1.00440123e-01],
#        [-1.15408915e+00, -1.76643607e+00],
#        [ 1.81194200e+00,  6.16287493e-01],
#        [ 4.16162637e-01, -8.32997975e-01],
#        [ 1.28852474e+00,  1.49568444e-01],
#        [ 6.77871268e-01, -2.92586445e-01],
#        [-1.41579778e+00, -2.01207768e+00],
#        [-2.00184146e-02,  2.18348093e-03],
#        [ 6.72177957e-02,  1.98696765e-01],
#        [-1.15408915e+00, -7.15090005e-02],
#        [ 1.28852474e+00, -1.54535863e+00],
#        [ 7.65107478e-01,  3.70645888e-01],
#        [-1.50303399e+00,  1.86905968e+00],
#        [-2.81727045e-01,  1.10757070e+00],
#        [ 1.98641442e+00,  1.08300654e+00],
#        [ 4.16162637e-01,  8.86493258e-01],
#        [ 8.52343688e-01,  1.25495567e+00],
#        [-2.20092367e+00,  2.67967697e+00],
#        [-1.07254625e-01, -4.39971408e-01],
#        [ 9.39579899e-01, -1.86469272e+00],
#        [-9.79616728e-01,  6.65415814e-01],
#        [-7.17908097e-01, -3.41714766e-01],
#        [-2.81727045e-01,  3.95210049e-01],
#        [ 5.90635058e-01,  1.42690479e+00],
#        [ 1.55023337e+00, -2.43458124e-01],
#        [-5.43435676e-01,  3.70645888e-01],
#        [ 1.20128853e+00,  1.98696765e-01],
#        [-9.79616728e-01,  7.63672456e-01],
#        [ 1.81194200e+00,  1.03387822e+00],
#        [-2.00184146e-02, -1.93838520e+00],
#        [-2.00184146e-02,  6.16287493e-01],
#        [-3.01194495e-02, -4.15407247e-01],
#        [-5.43435676e-01,  2.72389246e-01],
#        [-3.01194495e-02,  4.19774209e-01],
#        [-1.24132536e+00,  5.42595011e-01],
#        [ 8.52343688e-01,  3.70645888e-01],
#        [-1.06685294e+00,  1.10757070e+00],
#        [ 5.03398847e-01,  3.46081728e-01],
#        [-5.43435676e-01, -2.43458124e-01],
#        [ 6.72177957e-02, -1.05407542e+00],
#        [ 1.11405232e+00, -9.31254617e-01],
#        [ 6.77871268e-01, -2.23806795e-02],
#        [-8.92380518e-01, -1.45201482e-01],
#        [-6.30671887e-01, -7.15090005e-02],
#        [-2.00184146e-02, -1.42253783e+00],
#        [-2.37539609e+00,  1.45146895e+00],
#        [-1.06685294e+00, -2.92586445e-01],
#        [ 1.72470579e+00, -1.10320374e+00],
#        [ 2.16088684e+00, -9.60731610e-02],
#        [-8.05144307e-01,  1.27951983e+00],
#        [-9.79616728e-01,  1.77080304e+00],
#        [ 6.77871268e-01,  4.19774209e-01],
#        [ 6.72177957e-02, -1.44710199e+00],
#        [-2.00184146e-02, -5.38228050e-01],
#        [-7.17908097e-01,  2.45859953e+00],
#        [-1.06685294e+00,  4.19774209e-01],
#        [ 8.52343688e-01,  1.84449552e+00],
#        [-9.79616728e-01, -1.54535863e+00],
#        [ 4.16162637e-01,  1.49568444e-01],
#        [ 1.11405232e+00,  3.21517567e-01],
#        [-2.81727045e-01,  1.98696765e-01]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.41579778,  0.61628749],
#        [-0.63067189, -0.24345812],
#        [ 0.76510748, -0.68561301],
#        [-0.03011945, -1.42253783],
#        [-0.97961673, -0.09607316],
#        [-0.03011945,  0.83736494],
#        [-0.7179081 ,  0.91105742],
#        [ 0.15445401, -0.26802228],
#        [ 0.76510748,  0.34608173],
#        [-0.89238052, -0.80843381]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 88    0
# 46    0
# 66    1
# 9     0
# 22    0
# 91    1
# 47    0
# 99    1
# 11    1
# 25    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8
